# %% [markdown]
# <a href="https://colab.research.google.com/github/SanchoGDeMesa/-Rosal-DeMesa-grade8-library-Repo/blob/main/_rosal_demesa_grade8_library_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section
